# %%
import numpy as np
import pandas as pd
import options
import pain

# https://niftyinvest.com/max-pain/NIFTY?expiry=13JAN2022

# %%
df1 = pd.read_csv('/Users/kishor/Downloads/hcl2.csv')
df1.head(2)
df3 = options.Max_Pain(df1)
#df3 = pain.Max_Pain(df1)
# Out:
#  Market is Regular
# Strike Price where option Writer meet the Minimum Pain (loss) =  1240 Rs
# Put Call Ratio (PCR) =  0.6409
#
# Minimum Pain Strike Price with 5% correction =  1302.0 Rs
#
# Minimum Pain Strike Price with 3.5% correction =  1283.4 Rs
#
# Minimum Pain Strike Price with 2.5% correction =  1271.0 Rs

# %%
# usecols=[0,4]
#df1['Call OI\n'] = df1['Call OI\n'].apply(lambda x: str(x).replace('-','0'))
#df1['Put OI\n'] = df1['Put OI\n'].apply(lambda x: str(x).replace('-','0'))
#df1 = df1.replace('-',0)
#df1 = df1[df1["Call OI\n"],df1["Strike\n"],df1["Put OI\n"]]

#df1['Call OI\n']=pd.to_numeric(df1['Call OI\n'], downcast='integer', errors='coerce')
#df1['Put OI\n']=pd.to_numeric(df1['Put OI\n'], downcast='integer', errors='coerce')
